# %%
import matplotlib.pyplot as plt
import cv2
from kuntils import *

# %%
takina_eye = get_cropped_image_if_2_eyes("../test_img/Takina.jpeg")
plt.imshow(takina_eye)

# %%
image = "../test_img/Takina.jpeg"
arr_rin = image_to_array(image)
result_waifu_generate(arr_rin,"saved_model.pkl","class_dictionary.json")
# Out:
# ['Takina_Inoue']

# %%
image = "../test_img/4d0d71bc-acdb-48e2-b87e-afb88dd68a79.png"
arr_rin = image_to_array(image)

# %%
plt.imshow(cv2.imread(image))

# %%
result_waifu_generate(arr_rin,"saved_model.pkl","class_dictionary.json")
# Out:
# ['Shibuya_rin']

# %%
image = "../test_img/shibuya_img.jpg"
arr_rin = image_to_array(image)

# %%
result_waifu_generate(arr_rin,"saved_model.pkl","class_dictionary.json")
# Out:
# ['Takina_Inoue']

# %%
image = "../test_img/f86db16a-3081-4d1b-bc4c-a42a44bb3167.jpeg"
arr_takina = image_to_array(image)
result_waifu_generate(arr_rin,"saved_model.pkl","class_dictionary.json")
# Out:
# ['Takina_Inoue']

# %%
plt.imshow(cv2.imread(image))

# %%
arr_takina = image_to_array(image)
arr_takina
# Out:
# array([[ 62.,  64.,  65., ..., 135., 203., 231.]])
